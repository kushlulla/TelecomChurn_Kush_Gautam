# %%
#importing all packages we need for EDA
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime
import random

# %%
#getting the data 
churn_df=pd.read_csv("Data/train (1).csv")

# %%
churn_df.head()
# Out:
#    id  circle_id  loc_og_t2o_mou  std_og_t2o_mou  loc_ic_t2o_mou  \
# 0   0        109             0.0             0.0             0.0
# 1   1        109             0.0             0.0             0.0
# 2   2        109             0.0             0.0             0.0
# 3   3        109             0.0             0.0             0.0
# 4   4        109             0.0             0.0             0.0
#
#   last_date_of_month_6 last_date_of_month_7 last_date_of_month_8   arpu_6  \
# 0            6/30/2014            7/31/2014            8/31/2014   31.277
# 1            6/30/2014            7/31/2014            8/31/2014    0.000
# 2            6/30/2014            7/31/2014            8/31/2014   60.806
# 3            6/30/2014            7/31/2014            8/31/2014  156.362
# 4            6/30/2014            7/31/2014            8/31/2014  240.708
#
#     arpu_7  ...  sachet_3g_7  sachet_3g_8  fb_user_6  fb_user_7  fb_user_8  \
# 0   87.009  ...            0            0        NaN        NaN        NaN
# 1  122.787  ...            0            0        NaN        1.0        NaN
# 2  103.176  ...            0            0        NaN        NaN        NaN
# 3  205.260  ...            0            0        NaN        NaN        NaN
# 4  128.191  ...            1            0        1.0        1.0        1.0
#
#     aon  aug_vbc_3g  jul_vbc_3g  jun_vbc_3g  churn_probability
# 0  1958         0.0         0.0         0.0                  0
# 1   710         0.0         0.0         0.0                  0
# 2   882         0.0         0.0         0.0                  0
# 3   982         0.0         0.0         0.0                  0
# 4   647         0.0         0.0         0.0                  0
#
# [5 rows x 172 columns]

# %%
churn_df.describe()
# Out:
#                  id  circle_id  loc_og_t2o_mou  std_og_t2o_mou  \
# count  69999.000000    69999.0         69297.0         69297.0
# mean   34999.000000      109.0             0.0             0.0
# std    20207.115084        0.0             0.0             0.0
# min        0.000000      109.0             0.0             0.0
# 25%    17499.500000      109.0             0.0             0.0
# 50%    34999.000000      109.0             0.0             0.0
# 75%    52498.500000      109.0             0.0             0.0
# max    69998.000000      109.0             0.0             0.0
#
#        loc_ic_t2o_mou        arpu_6        arpu_7        arpu_8   onnet_mou_6  \
# count         69297.0  69999.000000  69999.000000  69999.000000  67231.000000
# mean              0.0    283.134365    278.185912    278.858826    133.153275
# std               0.0    334.213918    344.366927    351.924315    299.963093
# min               0.0  -2258.709000  -1289.715000   -945.808000      0.000000
# 25%               0.0     93.581000     86.714000     84.095000      7.410000
# 50%               0.0    197.484000    191.588000    192.234000     34.110000
# 75%               0.0    370.791000    365.369500    369.909000    119.390000
# max               0.0  27731.088000  35145.834000  33543.624000   7376.710000
#
#         onnet_mou_7  ...   sachet_3g_7   sachet_3g_8     fb_user_6  \
# count  67312.000000  ...  69999.000000  69999.000000  17568.000000
# mean     133.894438  ...      0.081444      0.085487      0.916325
# std      311.277193  ...      0.634547      0.680035      0.276907
# min        0.000000  ...      0.000000      0.000000      0.000000
# 25%        6.675000  ...      0.000000      0.000000      1.000000
# 50%       32.280000  ...      0.000000      0.000000      1.000000
# 75%      115.837500  ...      0.000000      0.000000      1.000000
# max     8157.780000  ...     33.000000     41.000000      1.000000
#
#           fb_user_7     fb_user_8           aon    aug_vbc_3g    jul_vbc_3g  \
# count  17865.000000  18417.000000  69999.000000  69999.000000  69999.000000
# mean       0.909544      0.890319   1220.639709     68.108597     65.935830
# std        0.286842      0.312501    952.426321    269.328659    267.899034
# min        0.000000      0.000000    180.000000      0.000000      0.000000
# 25%        1.000000      1.000000    468.000000      0.000000      0.000000
# 50%        1.000000      1.000000    868.000000      0.000000      0.000000
# 75%        1.000000      1.000000   1813.000000      0.000000      0.000000
# max        1.000000      1.000000   4337.000000  12916.220000   9165.600000
#
#         jun_vbc_3g  churn_probability
# count  69999.00000       69999.000000
# mean      60.07674           0.101887
# std      257.22681           0.302502
# min        0.00000           0.000000
# 25%        0.00000           0.000000
# 50%        0.00000           0.000000
# 75%        0.00000           0.000000
# max    11166.21000           1.000000
#
# [8 rows x 163 columns]

# %%
churn_df.info(verbose = True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69999 entries, 0 to 69998
# Data columns (total 172 columns):
#  #    Column                    Non-Null Count  Dtype
# ---   ------                    --------------  -----
#  0    id                        69999 non-null  int64
#  1    circle_id                 69999 non-null  int64
#  2    loc_og_t2o_mou            69297 non-null  float64
#  3    std_og_t2o_mou            69297 non-null  float64
#  4    loc_ic_t2o_mou            69297 non-null  float64
#  5    last_date_of_month_6      69999 non-null  object
#  6    last_date_of_month_7      69600 non-null  object
#  7    last_date_of_month_8      69266 non-null  object
#  8    arpu_6                    69999 non-null  float64
#  9    arpu_7                    69999 non-null  float64
#  10   arpu_8                    69999 non-null  float64
#  11   onnet_mou_6               67231 non-null  float64
#  12   onnet_mou_7               67312 non-null  float64
#  13   onnet_mou_8               66296 non-null  float64
#  14   offnet_mou_6              67231 non-null  float64
#  15   offnet_mou_7              67312 non-null  float64
#  16   offnet_mou_8              66296 non-null  float64
#  17   roam_ic_mou_6             67231 non-null  float64
#  18   roam_ic_mou_7             67312 non-null  float64
#  19   roam_ic_mou_8             66296 non-null  float64
#  20   roam_og_mou_6             67231 non-null  float64
#  21   roam_og_mou_7             67312 non-null  float64
#  22   roam_og_mou_8             66296 non-null  float64
#  23   loc_og_t2t_mou_6          67231 non-null  float64
#  24   loc_og_t2t_mou_7          67312 non-null  float64
#  25   loc_og_t2t_mou_8          66296 non-null  float64
#  26   loc_og_t2m_mou_6          67231 non-null  float64
#  27   loc_og_t2m_mou_7          67312 non-null  float64
#  28   loc_og_t2m_mou_8          66296 non-null  float64
#  29   loc_og_t2f_mou_6          67231 non-null  float64
#  30   loc_og_t2f_mou_7          67312 non-null  float64
#  31   loc_og_t2f_mou_8          66296 non-null  float64
#  32   loc_og_t2c_mou_6          67231 non-null  float64
#  33   loc_og_t2c_mou_7          67312 non-null  float64
#  34   loc_og_t2c_mou_8          66296 non-null  float64
#  35   loc_og_mou_6              67231 non-null  float64
#  36   loc_og_mou_7              67312 non-null  float64
#  37   loc_og_mou_8              66296 non-null  float64
#  38   std_og_t2t_mou_6          67231 non-null  float64
#  39   std_og_t2t_mou_7          67312 non-null  float64
#  40   std_og_t2t_mou_8          66296 non-null  float64
#  41   std_og_t2m_mou_6          67231 non-null  float64
#  42   std_og_t2m_mou_7          67312 non-null  float64
#  43   std_og_t2m_mou_8          66296 non-null  float64
#  44   std_og_t2f_mou_6          67231 non-null  float64
#  45   std_og_t2f_mou_7          67312 non-null  float64
#  46   std_og_t2f_mou_8          66296 non-null  float64
#  47   std_og_t2c_mou_6          67231 non-null  float64
#  48   std_og_t2c_mou_7          67312 non-null  float64
#  49   std_og_t2c_mou_8          66296 non-null  float64
#  50   std_og_mou_6              67231 non-null  float64
#  51   std_og_mou_7              67312 non-null  float64
#  52   std_og_mou_8              66296 non-null  float64
#  53   isd_og_mou_6              67231 non-null  float64
#  54   isd_og_mou_7              67312 non-null  float64
#  55   isd_og_mou_8              66296 non-null  float64
#  56   spl_og_mou_6              67231 non-null  float64
#  57   spl_og_mou_7              67312 non-null  float64
#  58   spl_og_mou_8              66296 non-null  float64
#  59   og_others_6               67231 non-null  float64
#  60   og_others_7               67312 non-null  float64
#  61   og_others_8               66296 non-null  float64
#  62   total_og_mou_6            69999 non-null  float64
#  63   total_og_mou_7            69999 non-null  float64
#  64   total_og_mou_8            69999 non-null  float64
#  65   loc_ic_t2t_mou_6          67231 non-null  float64
#  66   loc_ic_t2t_mou_7          67312 non-null  float64
#  67   loc_ic_t2t_mou_8          66296 non-null  float64
#  68   loc_ic_t2m_mou_6          67231 non-null  float64
#  69   loc_ic_t2m_mou_7          67312 non-null  float64
#  70   loc_ic_t2m_mou_8          66296 non-null  float64
#  71   loc_ic_t2f_mou_6          67231 non-null  float64
#  72   loc_ic_t2f_mou_7          67312 non-null  float64
#  73   loc_ic_t2f_mou_8          66296 non-null  float64
#  74   loc_ic_mou_6              67231 non-null  float64
#  75   loc_ic_mou_7              67312 non-null  float64
#  76   loc_ic_mou_8              66296 non-null  float64
#  77   std_ic_t2t_mou_6          67231 non-null  float64
#  78   std_ic_t2t_mou_7          67312 non-null  float64
#  79   std_ic_t2t_mou_8          66296 non-null  float64
#  80   std_ic_t2m_mou_6          67231 non-null  float64
#  81   std_ic_t2m_mou_7          67312 non-null  float64
#  82   std_ic_t2m_mou_8          66296 non-null  float64
#  83   std_ic_t2f_mou_6          67231 non-null  float64
#  84   std_ic_t2f_mou_7          67312 non-null  float64
#  85   std_ic_t2f_mou_8          66296 non-null  float64
#  86   std_ic_t2o_mou_6          67231 non-null  float64
#  87   std_ic_t2o_mou_7          67312 non-null  float64
#  88   std_ic_t2o_mou_8          66296 non-null  float64
#  89   std_ic_mou_6              67231 non-null  float64
#  90   std_ic_mou_7              67312 non-null  float64
#  91   std_ic_mou_8              66296 non-null  float64
#  92   total_ic_mou_6            69999 non-null  float64
#  93   total_ic_mou_7            69999 non-null  float64
#  94   total_ic_mou_8            69999 non-null  float64
#  95   spl_ic_mou_6              67231 non-null  float64
#  96   spl_ic_mou_7              67312 non-null  float64
#  97   spl_ic_mou_8              66296 non-null  float64
#  98   isd_ic_mou_6              67231 non-null  float64
#  99   isd_ic_mou_7              67312 non-null  float64
#  100  isd_ic_mou_8              66296 non-null  float64
#  101  ic_others_6               67231 non-null  float64
#  102  ic_others_7               67312 non-null  float64
#  103  ic_others_8               66296 non-null  float64
#  104  total_rech_num_6          69999 non-null  int64
#  105  total_rech_num_7          69999 non-null  int64
#  106  total_rech_num_8          69999 non-null  int64
#  107  total_rech_amt_6          69999 non-null  int64
#  108  total_rech_amt_7          69999 non-null  int64
#  109  total_rech_amt_8          69999 non-null  int64
#  110  max_rech_amt_6            69999 non-null  int64
#  111  max_rech_amt_7            69999 non-null  int64
#  112  max_rech_amt_8            69999 non-null  int64
#  113  date_of_last_rech_6       68898 non-null  object
#  114  date_of_last_rech_7       68765 non-null  object
#  115  date_of_last_rech_8       67538 non-null  object
#  116  last_day_rch_amt_6        69999 non-null  int64
#  117  last_day_rch_amt_7        69999 non-null  int64
#  118  last_day_rch_amt_8        69999 non-null  int64
#  119  date_of_last_rech_data_6  17568 non-null  object
#  120  date_of_last_rech_data_7  17865 non-null  object
#  121  date_of_last_rech_data_8  18417 non-null  object
#  122  total_rech_data_6         17568 non-null  float64
#  123  total_rech_data_7         17865 non-null  float64
#  124  total_rech_data_8         18417 non-null  float64
#  125  max_rech_data_6           17568 non-null  float64
#  126  max_rech_data_7           17865 non-null  float64
#  127  max_rech_data_8           18417 non-null  float64
#  128  count_rech_2g_6           17568 non-null  float64
#  129  count_rech_2g_7           17865 non-null  float64
#  130  count_rech_2g_8           18417 non-null  float64
#  131  count_rech_3g_6           17568 non-null  float64
#  132  count_rech_3g_7           17865 non-null  float64
#  133  count_rech_3g_8           18417 non-null  float64
#  134  av_rech_amt_data_6        17568 non-null  float64
#  135  av_rech_amt_data_7        17865 non-null  float64
#  136  av_rech_amt_data_8        18417 non-null  float64
#  137  vol_2g_mb_6               69999 non-null  float64
#  138  vol_2g_mb_7               69999 non-null  float64
#  139  vol_2g_mb_8               69999 non-null  float64
#  140  vol_3g_mb_6               69999 non-null  float64
#  141  vol_3g_mb_7               69999 non-null  float64
#  142  vol_3g_mb_8               69999 non-null  float64
#  143  arpu_3g_6                 17568 non-null  float64
#  144  arpu_3g_7                 17865 non-null  float64
#  145  arpu_3g_8                 18417 non-null  float64
#  146  arpu_2g_6                 17568 non-null  float64
#  147  arpu_2g_7                 17865 non-null  float64
#  148  arpu_2g_8                 18417 non-null  float64
#  149  night_pck_user_6          17568 non-null  float64
#  150  night_pck_user_7          17865 non-null  float64
#  151  night_pck_user_8          18417 non-null  float64
#  152  monthly_2g_6              69999 non-null  int64
#  153  monthly_2g_7              69999 non-null  int64
#  154  monthly_2g_8              69999 non-null  int64
#  155  sachet_2g_6               69999 non-null  int64
#  156  sachet_2g_7               69999 non-null  int64
#  157  sachet_2g_8               69999 non-null  int64
#  158  monthly_3g_6              69999 non-null  int64
#  159  monthly_3g_7              69999 non-null  int64
#  160  monthly_3g_8              69999 non-null  int64
#  161  sachet_3g_6               69999 non-null  int64
#  162  sachet_3g_7               69999 non-null  int64
#  163  sachet_3g_8               69999 non-null  int64
#  164  fb_user_6                 17568 non-null  float64
#  165  fb_user_7                 17865 non-null  float64
#  166  fb_user_8                 18417 non-null  float64
#  167  aon                       69999 non-null  int64
#  168  aug_vbc_3g                69999 non-null  float64
#  169  jul_vbc_3g                69999 non-null  float64
#  170  jun_vbc_3g                69999 non-null  float64
#  171  churn_probability         69999 non-null  int64
# dtypes: float64(135), int64(28), object(9)
# memory usage: 91.9+ MB

# %%
churn_df.last_date_of_month_6
# Out:
# 0        6/30/2014
# 1        6/30/2014
# 2        6/30/2014
# 3        6/30/2014
# 4        6/30/2014
#            ...
# 69994    6/30/2014
# 69995    6/30/2014
# 69996    6/30/2014
# 69997    6/30/2014
# 69998    6/30/2014
# Name: last_date_of_month_6, Length: 69999, dtype: object

# %%
percent_missing = churn_df.isnull().sum() * 100 / len(churn_df)
missing_value_df = pd.DataFrame({'column_name': churn_df.columns,
                                 'percent_missing': percent_missing})

# %%
missing_value_df.sort_values('percent_missing', inplace=True, ascending= False)

# %%
pd.set_option('display.max_rows', 200)
missing_value_df
# Out:
#                                        column_name  percent_missing
# arpu_3g_6                                arpu_3g_6        74.902499
# count_rech_2g_6                    count_rech_2g_6        74.902499
# night_pck_user_6                  night_pck_user_6        74.902499
# arpu_2g_6                                arpu_2g_6        74.902499
# date_of_last_rech_data_6  date_of_last_rech_data_6        74.902499
# total_rech_data_6                total_rech_data_6        74.902499
# av_rech_amt_data_6              av_rech_amt_data_6        74.902499
# max_rech_data_6                    max_rech_data_6        74.902499
# count_rech_3g_6                    count_rech_3g_6        74.902499
# fb_user_6                                fb_user_6        74.902499
# night_pck_user_7                  night_pck_user_7        74.478207
# date_of_last_rech_data_7  date_of_last_rech_data_7        74.478207
# total_rech_data_7                total_rech_data_7        74.478207
# max_rech_data_7                    max_rech_data_7        74.478207
# fb_user_7                                fb_user_7        74.478207
# count_rech_2g_7                    count_rech_2g_7        74.478207
# count_rech_3g_7                    count_rech_3g_7        74.478207
# arpu_3g_7                                arpu_3g_7        74.478207
# av_rech_amt_data_7              av_rech_amt_data_7        74.478207
# arpu_2g_7                                arpu_2g_7        74.478207
# count_rech_2g_8                    count_rech_2g_8        73.689624
# av_rech_amt_data_8              av_rech_amt_data_8        73.689624
# night_pck_user_8                  night_pck_user_8        73.689624
# max_rech_data_8                    max_rech_data_8        73.689624
# total_rech_data_8                total_rech_data_8        73.689624
# arpu_2g_8                                arpu_2g_8        73.689624
# arpu_3g_8                                arpu_3g_8        73.689624
# date_of_last_rech_data_8  date_of_last_rech_data_8        73.689624
# fb_user_8                                fb_user_8        73.689624
# count_rech_3g_8                    count_rech_3g_8        73.689624
# isd_og_mou_8                          isd_og_mou_8         5.290076
# std_ic_t2o_mou_8                  std_ic_t2o_mou_8         5.290076
# std_og_t2c_mou_8                  std_og_t2c_mou_8         5.290076
# std_ic_t2f_mou_8                  std_ic_t2f_mou_8         5.290076
# std_og_mou_8                          std_og_mou_8         5.290076
# std_ic_t2m_mou_8                  std_ic_t2m_mou_8         5.290076
# std_ic_mou_8                          std_ic_mou_8         5.290076
# std_ic_t2t_mou_8                  std_ic_t2t_mou_8         5.290076
# og_others_8                            og_others_8         5.290076
# spl_og_mou_8                          spl_og_mou_8         5.290076
# loc_ic_t2m_mou_8                  loc_ic_t2m_mou_8         5.290076
# loc_ic_mou_8                          loc_ic_mou_8         5.290076
# loc_ic_t2f_mou_8                  loc_ic_t2f_mou_8         5.290076
# std_og_t2f_mou_8                  std_og_t2f_mou_8         5.290076
# loc_og_t2c_mou_8                  loc_og_t2c_mou_8         5.290076
# ic_others_8                            ic_others_8         5.290076
# loc_og_mou_8                          loc_og_mou_8         5.290076
# onnet_mou_8                            onnet_mou_8         5.290076
# offnet_mou_8                          offnet_mou_8         5.290076
# roam_ic_mou_8                        roam_ic_mou_8         5.290076
# roam_og_mou_8                        roam_og_mou_8         5.290076
# loc_og_t2t_mou_8                  loc_og_t2t_mou_8         5.290076
# loc_og_t2m_mou_8                  loc_og_t2m_mou_8         5.290076
# loc_og_t2f_mou_8                  loc_og_t2f_mou_8         5.290076
# std_og_t2m_mou_8                  std_og_t2m_mou_8         5.290076
# loc_ic_t2t_mou_8                  loc_ic_t2t_mou_8         5.290076
# isd_ic_mou_8                          isd_ic_mou_8         5.290076
# std_og_t2t_mou_8                  std_og_t2t_mou_8         5.290076
# spl_ic_mou_8                          spl_ic_mou_8         5.290076
# std_ic_t2m_mou_6                  std_ic_t2m_mou_6         3.954342
# std_ic_t2t_mou_6                  std_ic_t2t_mou_6         3.954342
# loc_ic_t2m_mou_6                  loc_ic_t2m_mou_6         3.954342
# ic_others_6                            ic_others_6         3.954342
# loc_ic_mou_6                          loc_ic_mou_6         3.954342
# std_ic_t2f_mou_6                  std_ic_t2f_mou_6         3.954342
# isd_ic_mou_6                          isd_ic_mou_6         3.954342
# std_ic_mou_6                          std_ic_mou_6         3.954342
# spl_ic_mou_6                          spl_ic_mou_6         3.954342
# std_ic_t2o_mou_6                  std_ic_t2o_mou_6         3.954342
# loc_ic_t2f_mou_6                  loc_ic_t2f_mou_6         3.954342
# isd_og_mou_6                          isd_og_mou_6         3.954342
# std_og_t2m_mou_6                  std_og_t2m_mou_6         3.954342
# std_og_t2f_mou_6                  std_og_t2f_mou_6         3.954342
# loc_og_mou_6                          loc_og_mou_6         3.954342
# loc_og_t2c_mou_6                  loc_og_t2c_mou_6         3.954342
# std_og_t2c_mou_6                  std_og_t2c_mou_6         3.954342
# loc_og_t2f_mou_6                  loc_og_t2f_mou_6         3.954342
# loc_og_t2m_mou_6                  loc_og_t2m_mou_6         3.954342
# std_og_mou_6                          std_og_mou_6         3.954342
# loc_og_t2t_mou_6                  loc_og_t2t_mou_6         3.954342
# std_og_t2t_mou_6                  std_og_t2t_mou_6         3.954342
# loc_ic_t2t_mou_6                  loc_ic_t2t_mou_6         3.954342
# spl_og_mou_6                          spl_og_mou_6         3.954342
# onnet_mou_6                            onnet_mou_6         3.954342
# roam_ic_mou_6                        roam_ic_mou_6         3.954342
# og_others_6                            og_others_6         3.954342
# roam_og_mou_6                        roam_og_mou_6         3.954342
# offnet_mou_6                          offnet_mou_6         3.954342
# roam_og_mou_7                        roam_og_mou_7         3.838626
# ic_others_7                            ic_others_7         3.838626
# loc_og_mou_7                          loc_og_mou_7         3.838626
# onnet_mou_7                            onnet_mou_7         3.838626
# loc_ic_t2t_mou_7                  loc_ic_t2t_mou_7         3.838626
# loc_og_t2f_mou_7                  loc_og_t2f_mou_7         3.838626
# loc_og_t2c_mou_7                  loc_og_t2c_mou_7         3.838626
# offnet_mou_7                          offnet_mou_7         3.838626
# loc_og_t2m_mou_7                  loc_og_t2m_mou_7         3.838626
# roam_ic_mou_7                        roam_ic_mou_7         3.838626
# std_og_t2t_mou_7                  std_og_t2t_mou_7         3.838626
# loc_og_t2t_mou_7                  loc_og_t2t_mou_7         3.838626
# loc_ic_t2m_mou_7                  loc_ic_t2m_mou_7         3.838626
# isd_ic_mou_7                          isd_ic_mou_7         3.838626
# loc_ic_t2f_mou_7                  loc_ic_t2f_mou_7         3.838626
# loc_ic_mou_7                          loc_ic_mou_7         3.838626
# spl_og_mou_7                          spl_og_mou_7         3.838626
# std_ic_t2t_mou_7                  std_ic_t2t_mou_7         3.838626
# isd_og_mou_7                          isd_og_mou_7         3.838626
# std_ic_t2m_mou_7                  std_ic_t2m_mou_7         3.838626
# std_og_mou_7                          std_og_mou_7         3.838626
# std_ic_t2f_mou_7                  std_ic_t2f_mou_7         3.838626
# std_og_t2m_mou_7                  std_og_t2m_mou_7         3.838626
# std_ic_t2o_mou_7                  std_ic_t2o_mou_7         3.838626
# std_og_t2c_mou_7                  std_og_t2c_mou_7         3.838626
# std_ic_mou_7                          std_ic_mou_7         3.838626
# std_og_t2f_mou_7                  std_og_t2f_mou_7         3.838626
# og_others_7                            og_others_7         3.838626
# spl_ic_mou_7                          spl_ic_mou_7         3.838626
# date_of_last_rech_8            date_of_last_rech_8         3.515765
# date_of_last_rech_7            date_of_last_rech_7         1.762882
# date_of_last_rech_6            date_of_last_rech_6         1.572880
# last_date_of_month_8          last_date_of_month_8         1.047158
# loc_ic_t2o_mou                      loc_ic_t2o_mou         1.002871
# std_og_t2o_mou                      std_og_t2o_mou         1.002871
# loc_og_t2o_mou                      loc_og_t2o_mou         1.002871
# last_date_of_month_7          last_date_of_month_7         0.570008
# vol_3g_mb_8                            vol_3g_mb_8         0.000000
# aon                                            aon         0.000000
# aug_vbc_3g                              aug_vbc_3g         0.000000
# jul_vbc_3g                              jul_vbc_3g         0.000000
# jun_vbc_3g                              jun_vbc_3g         0.000000
# sachet_3g_8                            sachet_3g_8         0.000000
# sachet_3g_7                            sachet_3g_7         0.000000
# sachet_3g_6                            sachet_3g_6         0.000000
# monthly_2g_6                          monthly_2g_6         0.000000
# monthly_2g_7                          monthly_2g_7         0.000000
# monthly_2g_8                          monthly_2g_8         0.000000
# sachet_2g_6                            sachet_2g_6         0.000000
# sachet_2g_7                            sachet_2g_7         0.000000
# sachet_2g_8                            sachet_2g_8         0.000000
# monthly_3g_8                          monthly_3g_8         0.000000
# monthly_3g_7                          monthly_3g_7         0.000000
# monthly_3g_6                          monthly_3g_6         0.000000
# id                                              id         0.000000
# vol_3g_mb_7                            vol_3g_mb_7         0.000000
# total_rech_num_7                  total_rech_num_7         0.000000
# last_date_of_month_6          last_date_of_month_6         0.000000
# arpu_6                                      arpu_6         0.000000
# arpu_7                                      arpu_7         0.000000
# arpu_8                                      arpu_8         0.000000
# total_og_mou_6                      total_og_mou_6         0.000000
# total_og_mou_7                      total_og_mou_7         0.000000
# total_og_mou_8                      total_og_mou_8         0.000000
# circle_id                                circle_id         0.000000
# total_ic_mou_6                      total_ic_mou_6         0.000000
# total_ic_mou_7                      total_ic_mou_7         0.000000
# total_ic_mou_8                      total_ic_mou_8         0.000000
# total_rech_num_6                  total_rech_num_6         0.000000
# total_rech_num_8                  total_rech_num_8         0.000000
# vol_3g_mb_6                            vol_3g_mb_6         0.000000
# total_rech_amt_6                  total_rech_amt_6         0.000000
# total_rech_amt_7                  total_rech_amt_7         0.000000
# total_rech_amt_8                  total_rech_amt_8         0.000000
# max_rech_amt_6                      max_rech_amt_6         0.000000
# max_rech_amt_7                      max_rech_amt_7         0.000000
# max_rech_amt_8                      max_rech_amt_8         0.000000
# last_day_rch_amt_6              last_day_rch_amt_6         0.000000
# last_day_rch_amt_7              last_day_rch_amt_7         0.000000
# last_day_rch_amt_8              last_day_rch_amt_8         0.000000
# vol_2g_mb_6                            vol_2g_mb_6         0.000000
# vol_2g_mb_7                            vol_2g_mb_7         0.000000
# vol_2g_mb_8                            vol_2g_mb_8         0.000000
# churn_probability                churn_probability         0.000000

# %%
def FixDate(arr):
    fx='%m/%d/%Y'
    out=pd.to_datetime(arr,format=fx)
    return out

# %%
#Since all the data is numeric except for the date we can grab all the date columns at once to fix them
DateList=list(churn_df.select_dtypes(['object']).columns)

# %%
DateList
# Out:
# ['last_date_of_month_6',
#  'last_date_of_month_7',
#  'last_date_of_month_8',
#  'date_of_last_rech_6',
#  'date_of_last_rech_7',
#  'date_of_last_rech_8',
#  'date_of_last_rech_data_6',
#  'date_of_last_rech_data_7',
#  'date_of_last_rech_data_8']

# %%
for x in DateList:
    churn_df[x]=FixDate(churn_df[x])
churn_df.info(verbose = True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69999 entries, 0 to 69998
# Data columns (total 172 columns):
#  #    Column                    Non-Null Count  Dtype
# ---   ------                    --------------  -----
#  0    id                        69999 non-null  int64
#  1    circle_id                 69999 non-null  int64
#  2    loc_og_t2o_mou            69297 non-null  float64
#  3    std_og_t2o_mou            69297 non-null  float64
#  4    loc_ic_t2o_mou            69297 non-null  float64
#  5    last_date_of_month_6      69999 non-null  datetime64[ns]
#  6    last_date_of_month_7      69600 non-null  datetime64[ns]
#  7    last_date_of_month_8      69266 non-null  datetime64[ns]
#  8    arpu_6                    69999 non-null  float64
#  9    arpu_7                    69999 non-null  float64
#  10   arpu_8                    69999 non-null  float64
#  11   onnet_mou_6               67231 non-null  float64
#  12   onnet_mou_7               67312 non-null  float64
#  13   onnet_mou_8               66296 non-null  float64
#  14   offnet_mou_6              67231 non-null  float64
#  15   offnet_mou_7              67312 non-null  float64
#  16   offnet_mou_8              66296 non-null  float64
#  17   roam_ic_mou_6             67231 non-null  float64
#  18   roam_ic_mou_7             67312 non-null  float64
#  19   roam_ic_mou_8             66296 non-null  float64
#  20   roam_og_mou_6             67231 non-null  float64
#  21   roam_og_mou_7             67312 non-null  float64
#  22   roam_og_mou_8             66296 non-null  float64
#  23   loc_og_t2t_mou_6          67231 non-null  float64
#  24   loc_og_t2t_mou_7          67312 non-null  float64
#  25   loc_og_t2t_mou_8          66296 non-null  float64
#  26   loc_og_t2m_mou_6          67231 non-null  float64
#  27   loc_og_t2m_mou_7          67312 non-null  float64
#  28   loc_og_t2m_mou_8          66296 non-null  float64
#  29   loc_og_t2f_mou_6          67231 non-null  float64
#  30   loc_og_t2f_mou_7          67312 non-null  float64
#  31   loc_og_t2f_mou_8          66296 non-null  float64
#  32   loc_og_t2c_mou_6          67231 non-null  float64
#  33   loc_og_t2c_mou_7          67312 non-null  float64
#  34   loc_og_t2c_mou_8          66296 non-null  float64
#  35   loc_og_mou_6              67231 non-null  float64
#  36   loc_og_mou_7              67312 non-null  float64
#  37   loc_og_mou_8              66296 non-null  float64
#  38   std_og_t2t_mou_6          67231 non-null  float64
#  39   std_og_t2t_mou_7          67312 non-null  float64
#  40   std_og_t2t_mou_8          66296 non-null  float64
#  41   std_og_t2m_mou_6          67231 non-null  float64
#  42   std_og_t2m_mou_7          67312 non-null  float64
#  43   std_og_t2m_mou_8          66296 non-null  float64
#  44   std_og_t2f_mou_6          67231 non-null  float64
#  45   std_og_t2f_mou_7          67312 non-null  float64
#  46   std_og_t2f_mou_8          66296 non-null  float64
#  47   std_og_t2c_mou_6          67231 non-null  float64
#  48   std_og_t2c_mou_7          67312 non-null  float64
#  49   std_og_t2c_mou_8          66296 non-null  float64
#  50   std_og_mou_6              67231 non-null  float64
#  51   std_og_mou_7              67312 non-null  float64
#  52   std_og_mou_8              66296 non-null  float64
#  53   isd_og_mou_6              67231 non-null  float64
#  54   isd_og_mou_7              67312 non-null  float64
#  55   isd_og_mou_8              66296 non-null  float64
#  56   spl_og_mou_6              67231 non-null  float64
#  57   spl_og_mou_7              67312 non-null  float64
#  58   spl_og_mou_8              66296 non-null  float64
#  59   og_others_6               67231 non-null  float64
#  60   og_others_7               67312 non-null  float64
#  61   og_others_8               66296 non-null  float64
#  62   total_og_mou_6            69999 non-null  float64
#  63   total_og_mou_7            69999 non-null  float64
#  64   total_og_mou_8            69999 non-null  float64
#  65   loc_ic_t2t_mou_6          67231 non-null  float64
#  66   loc_ic_t2t_mou_7          67312 non-null  float64
#  67   loc_ic_t2t_mou_8          66296 non-null  float64
#  68   loc_ic_t2m_mou_6          67231 non-null  float64
#  69   loc_ic_t2m_mou_7          67312 non-null  float64
#  70   loc_ic_t2m_mou_8          66296 non-null  float64
#  71   loc_ic_t2f_mou_6          67231 non-null  float64
#  72   loc_ic_t2f_mou_7          67312 non-null  float64
#  73   loc_ic_t2f_mou_8          66296 non-null  float64
#  74   loc_ic_mou_6              67231 non-null  float64
#  75   loc_ic_mou_7              67312 non-null  float64
#  76   loc_ic_mou_8              66296 non-null  float64
#  77   std_ic_t2t_mou_6          67231 non-null  float64
#  78   std_ic_t2t_mou_7          67312 non-null  float64
#  79   std_ic_t2t_mou_8          66296 non-null  float64
#  80   std_ic_t2m_mou_6          67231 non-null  float64
#  81   std_ic_t2m_mou_7          67312 non-null  float64
#  82   std_ic_t2m_mou_8          66296 non-null  float64
#  83   std_ic_t2f_mou_6          67231 non-null  float64
#  84   std_ic_t2f_mou_7          67312 non-null  float64
#  85   std_ic_t2f_mou_8          66296 non-null  float64
#  86   std_ic_t2o_mou_6          67231 non-null  float64
#  87   std_ic_t2o_mou_7          67312 non-null  float64
#  88   std_ic_t2o_mou_8          66296 non-null  float64
#  89   std_ic_mou_6              67231 non-null  float64
#  90   std_ic_mou_7              67312 non-null  float64
#  91   std_ic_mou_8              66296 non-null  float64
#  92   total_ic_mou_6            69999 non-null  float64
#  93   total_ic_mou_7            69999 non-null  float64
#  94   total_ic_mou_8            69999 non-null  float64
#  95   spl_ic_mou_6              67231 non-null  float64
#  96   spl_ic_mou_7              67312 non-null  float64
#  97   spl_ic_mou_8              66296 non-null  float64
#  98   isd_ic_mou_6              67231 non-null  float64
#  99   isd_ic_mou_7              67312 non-null  float64
#  100  isd_ic_mou_8              66296 non-null  float64
#  101  ic_others_6               67231 non-null  float64
#  102  ic_others_7               67312 non-null  float64
#  103  ic_others_8               66296 non-null  float64
#  104  total_rech_num_6          69999 non-null  int64
#  105  total_rech_num_7          69999 non-null  int64
#  106  total_rech_num_8          69999 non-null  int64
#  107  total_rech_amt_6          69999 non-null  int64
#  108  total_rech_amt_7          69999 non-null  int64
#  109  total_rech_amt_8          69999 non-null  int64
#  110  max_rech_amt_6            69999 non-null  int64
#  111  max_rech_amt_7            69999 non-null  int64
#  112  max_rech_amt_8            69999 non-null  int64
#  113  date_of_last_rech_6       68898 non-null  datetime64[ns]
#  114  date_of_last_rech_7       68765 non-null  datetime64[ns]
#  115  date_of_last_rech_8       67538 non-null  datetime64[ns]
#  116  last_day_rch_amt_6        69999 non-null  int64
#  117  last_day_rch_amt_7        69999 non-null  int64
#  118  last_day_rch_amt_8        69999 non-null  int64
#  119  date_of_last_rech_data_6  17568 non-null  datetime64[ns]
#  120  date_of_last_rech_data_7  17865 non-null  datetime64[ns]
#  121  date_of_last_rech_data_8  18417 non-null  datetime64[ns]
#  122  total_rech_data_6         17568 non-null  float64
#  123  total_rech_data_7         17865 non-null  float64
#  124  total_rech_data_8         18417 non-null  float64
#  125  max_rech_data_6           17568 non-null  float64
#  126  max_rech_data_7           17865 non-null  float64
#  127  max_rech_data_8           18417 non-null  float64
#  128  count_rech_2g_6           17568 non-null  float64
#  129  count_rech_2g_7           17865 non-null  float64
#  130  count_rech_2g_8           18417 non-null  float64
#  131  count_rech_3g_6           17568 non-null  float64
#  132  count_rech_3g_7           17865 non-null  float64
#  133  count_rech_3g_8           18417 non-null  float64
#  134  av_rech_amt_data_6        17568 non-null  float64
#  135  av_rech_amt_data_7        17865 non-null  float64
#  136  av_rech_amt_data_8        18417 non-null  float64
#  137  vol_2g_mb_6               69999 non-null  float64
#  138  vol_2g_mb_7               69999 non-null  float64
#  139  vol_2g_mb_8               69999 non-null  float64
#  140  vol_3g_mb_6               69999 non-null  float64
#  141  vol_3g_mb_7               69999 non-null  float64
#  142  vol_3g_mb_8               69999 non-null  float64
#  143  arpu_3g_6                 17568 non-null  float64
#  144  arpu_3g_7                 17865 non-null  float64
#  145  arpu_3g_8                 18417 non-null  float64
#  146  arpu_2g_6                 17568 non-null  float64
#  147  arpu_2g_7                 17865 non-null  float64
#  148  arpu_2g_8                 18417 non-null  float64
#  149  night_pck_user_6          17568 non-null  float64
#  150  night_pck_user_7          17865 non-null  float64
#  151  night_pck_user_8          18417 non-null  float64
#  152  monthly_2g_6              69999 non-null  int64
#  153  monthly_2g_7              69999 non-null  int64
#  154  monthly_2g_8              69999 non-null  int64
#  155  sachet_2g_6               69999 non-null  int64
#  156  sachet_2g_7               69999 non-null  int64
#  157  sachet_2g_8               69999 non-null  int64
#  158  monthly_3g_6              69999 non-null  int64
#  159  monthly_3g_7              69999 non-null  int64
#  160  monthly_3g_8              69999 non-null  int64
#  161  sachet_3g_6               69999 non-null  int64
#  162  sachet_3g_7               69999 non-null  int64
#  163  sachet_3g_8               69999 non-null  int64
#  164  fb_user_6                 17568 non-null  float64
#  165  fb_user_7                 17865 non-null  float64
#  166  fb_user_8                 18417 non-null  float64
#  167  aon                       69999 non-null  int64
#  168  aug_vbc_3g                69999 non-null  float64
#  169  jul_vbc_3g                69999 non-null  float64
#  170  jun_vbc_3g                69999 non-null  float64
#  171  churn_probability         69999 non-null  int64
# dtypes: datetime64[ns](9), float64(135), int64(28)
# memory usage: 91.9 MB

# %% [markdown]
# ### All Data types Fixed.

# %%
#since most of the missing data is in the recharge columns lets look at them 
amt_recharge_col =  churn_df.columns[churn_df.columns.str.contains('rech_amt|rech_data')]
churn_df.loc[:,amt_recharge_col].describe()
# Out:
#        total_rech_amt_6  total_rech_amt_7  total_rech_amt_8  max_rech_amt_6  \
# count      69999.000000      69999.000000      69999.000000    69999.000000
# mean         328.139788        322.376363        323.846355      104.569265
# std          404.211068        411.070120        426.181405      121.407701
# min            0.000000          0.000000          0.000000        0.000000
# 25%          110.000000        100.000000         90.000000       30.000000
# 50%          229.000000        220.000000        225.000000      110.000000
# 75%          438.000000        430.000000        436.000000      120.000000
# max        35190.000000      40335.000000      45320.000000     4010.000000
#
#        max_rech_amt_7  max_rech_amt_8  total_rech_data_6  total_rech_data_7  \
# count    69999.000000    69999.000000       17568.000000       17865.000000
# mean       104.137573      107.540351           2.467612           2.679989
# std        120.782543      124.396750           2.794610           3.073472
# min          0.000000        0.000000           1.000000           1.000000
# 25%         30.000000       30.000000           1.000000           1.000000
# 50%        110.000000       98.000000           1.000000           2.000000
# 75%        128.000000      144.000000           3.000000           3.000000
# max       3299.000000     4449.000000          61.000000          54.000000
#
#        total_rech_data_8  max_rech_data_6  max_rech_data_7  max_rech_data_8  \
# count       18417.000000     17568.000000     17865.000000     18417.000000
# mean            2.652441       126.500000       126.402071       125.374925
# std             3.101265       109.352573       109.459266       109.648799
# min             1.000000         1.000000         1.000000         1.000000
# 25%             1.000000        25.000000        25.000000        25.000000
# 50%             1.000000       145.000000       145.000000       145.000000
# 75%             3.000000       177.000000       177.000000       179.000000
# max            60.000000      1555.000000      1555.000000      1555.000000
#
#        av_rech_amt_data_6  av_rech_amt_data_7  av_rech_amt_data_8
# count        17568.000000        17865.000000        18417.000000
# mean           192.831096          201.455940          196.815792
# std            190.623115          198.346141          192.280532
# min              1.000000            1.000000            1.000000
# 25%             82.000000           92.000000           84.000000
# 50%            154.000000          154.000000          154.000000
# 75%            252.000000          252.000000          252.000000
# max           5920.000000         4365.000000         4076.000000

# %% [markdown]
# ### Since we can see that the missing values are numeric and cannot have any caluculated value except 0 we can fill them with 0

# %%
for x in amt_recharge_col:
    churn_df[x]=churn_df[x].fillna(0)

# %%
percent_missing = churn_df.isnull().sum() * 100 / len(churn_df)
missing_value_df = pd.DataFrame({'column_name': churn_df.columns,
                                 'percent_missing': percent_missing})
missing_value_df.sort_values('percent_missing', inplace=True, ascending= False)
missing_value_df[missing_value_df.percent_missing>0]
# Out:
#                                column_name  percent_missing
# fb_user_6                        fb_user_6        74.902499
# count_rech_3g_6            count_rech_3g_6        74.902499
# night_pck_user_6          night_pck_user_6        74.902499
# arpu_2g_6                        arpu_2g_6        74.902499
# count_rech_2g_6            count_rech_2g_6        74.902499
# arpu_3g_6                        arpu_3g_6        74.902499
# night_pck_user_7          night_pck_user_7        74.478207
# arpu_3g_7                        arpu_3g_7        74.478207
# fb_user_7                        fb_user_7        74.478207
# arpu_2g_7                        arpu_2g_7        74.478207
# count_rech_2g_7            count_rech_2g_7        74.478207
# count_rech_3g_7            count_rech_3g_7        74.478207
# arpu_3g_8                        arpu_3g_8        73.689624
# arpu_2g_8                        arpu_2g_8        73.689624
# count_rech_2g_8            count_rech_2g_8        73.689624
# fb_user_8                        fb_user_8        73.689624
# night_pck_user_8          night_pck_user_8        73.689624
# count_rech_3g_8            count_rech_3g_8        73.689624
# std_og_t2f_mou_8          std_og_t2f_mou_8         5.290076
# loc_og_mou_8                  loc_og_mou_8         5.290076
# std_ic_t2t_mou_8          std_ic_t2t_mou_8         5.290076
# std_og_t2t_mou_8          std_og_t2t_mou_8         5.290076
# loc_ic_mou_8                  loc_ic_mou_8         5.290076
# std_og_t2m_mou_8          std_og_t2m_mou_8         5.290076
# loc_ic_t2f_mou_8          loc_ic_t2f_mou_8         5.290076
# std_ic_mou_8                  std_ic_mou_8         5.290076
# loc_ic_t2m_mou_8          loc_ic_t2m_mou_8         5.290076
# std_og_t2c_mou_8          std_og_t2c_mou_8         5.290076
# loc_ic_t2t_mou_8          loc_ic_t2t_mou_8         5.290076
# std_og_mou_8                  std_og_mou_8         5.290076
# isd_og_mou_8                  isd_og_mou_8         5.290076
# loc_og_t2c_mou_8          loc_og_t2c_mou_8         5.290076
# og_others_8                    og_others_8         5.290076
# std_ic_t2m_mou_8          std_ic_t2m_mou_8         5.290076
# spl_og_mou_8                  spl_og_mou_8         5.290076
# isd_ic_mou_8                  isd_ic_mou_8         5.290076
# std_ic_t2o_mou_8          std_ic_t2o_mou_8         5.290076
# onnet_mou_8                    onnet_mou_8         5.290076
# loc_og_t2f_mou_8          loc_og_t2f_mou_8         5.290076
# offnet_mou_8                  offnet_mou_8         5.290076
# roam_ic_mou_8                roam_ic_mou_8         5.290076
# ic_others_8                    ic_others_8         5.290076
# loc_og_t2m_mou_8          loc_og_t2m_mou_8         5.290076
# roam_og_mou_8                roam_og_mou_8         5.290076
# spl_ic_mou_8                  spl_ic_mou_8         5.290076
# std_ic_t2f_mou_8          std_ic_t2f_mou_8         5.290076
# loc_og_t2t_mou_8          loc_og_t2t_mou_8         5.290076
# std_ic_t2f_mou_6          std_ic_t2f_mou_6         3.954342
# ic_others_6                    ic_others_6         3.954342
# loc_ic_t2t_mou_6          loc_ic_t2t_mou_6         3.954342
# loc_ic_t2f_mou_6          loc_ic_t2f_mou_6         3.954342
# isd_ic_mou_6                  isd_ic_mou_6         3.954342
# spl_ic_mou_6                  spl_ic_mou_6         3.954342
# loc_ic_mou_6                  loc_ic_mou_6         3.954342
# og_others_6                    og_others_6         3.954342
# std_ic_t2t_mou_6          std_ic_t2t_mou_6         3.954342
# std_ic_mou_6                  std_ic_mou_6         3.954342
# std_ic_t2m_mou_6          std_ic_t2m_mou_6         3.954342
# std_ic_t2o_mou_6          std_ic_t2o_mou_6         3.954342
# loc_ic_t2m_mou_6          loc_ic_t2m_mou_6         3.954342
# std_og_t2f_mou_6          std_og_t2f_mou_6         3.954342
# std_og_t2t_mou_6          std_og_t2t_mou_6         3.954342
# std_og_t2m_mou_6          std_og_t2m_mou_6         3.954342
# loc_og_t2t_mou_6          loc_og_t2t_mou_6         3.954342
# loc_og_t2c_mou_6          loc_og_t2c_mou_6         3.954342
# loc_og_mou_6                  loc_og_mou_6         3.954342
# roam_og_mou_6                roam_og_mou_6         3.954342
# std_og_t2c_mou_6          std_og_t2c_mou_6         3.954342
# roam_ic_mou_6                roam_ic_mou_6         3.954342
# loc_og_t2f_mou_6          loc_og_t2f_mou_6         3.954342
# std_og_mou_6                  std_og_mou_6         3.954342
# offnet_mou_6                  offnet_mou_6         3.954342
# isd_og_mou_6                  isd_og_mou_6         3.954342
# onnet_mou_6                    onnet_mou_6         3.954342
# spl_og_mou_6                  spl_og_mou_6         3.954342
# loc_og_t2m_mou_6          loc_og_t2m_mou_6         3.954342
# loc_og_t2m_mou_7          loc_og_t2m_mou_7         3.838626
# std_ic_mou_7                  std_ic_mou_7         3.838626
# spl_ic_mou_7                  spl_ic_mou_7         3.838626
# og_others_7                    og_others_7         3.838626
# spl_og_mou_7                  spl_og_mou_7         3.838626
# isd_ic_mou_7                  isd_ic_mou_7         3.838626
# roam_og_mou_7                roam_og_mou_7         3.838626
# ic_others_7                    ic_others_7         3.838626
# roam_ic_mou_7                roam_ic_mou_7         3.838626
# offnet_mou_7                  offnet_mou_7         3.838626
# onnet_mou_7                    onnet_mou_7         3.838626
# loc_og_t2f_mou_7          loc_og_t2f_mou_7         3.838626
# loc_og_t2t_mou_7          loc_og_t2t_mou_7         3.838626
# std_ic_t2o_mou_7          std_ic_t2o_mou_7         3.838626
# std_ic_t2t_mou_7          std_ic_t2t_mou_7         3.838626
# isd_og_mou_7                  isd_og_mou_7         3.838626
# std_og_mou_7                  std_og_mou_7         3.838626
# loc_ic_t2t_mou_7          loc_ic_t2t_mou_7         3.838626
# loc_ic_t2m_mou_7          loc_ic_t2m_mou_7         3.838626
# loc_ic_t2f_mou_7          loc_ic_t2f_mou_7         3.838626
# std_og_t2f_mou_7          std_og_t2f_mou_7         3.838626
# loc_ic_mou_7                  loc_ic_mou_7         3.838626
# std_og_t2m_mou_7          std_og_t2m_mou_7         3.838626
# std_og_t2c_mou_7          std_og_t2c_mou_7         3.838626
# std_og_t2t_mou_7          std_og_t2t_mou_7         3.838626
# std_ic_t2f_mou_7          std_ic_t2f_mou_7         3.838626
# std_ic_t2m_mou_7          std_ic_t2m_mou_7         3.838626
# loc_og_t2c_mou_7          loc_og_t2c_mou_7         3.838626
# loc_og_mou_7                  loc_og_mou_7         3.838626
# date_of_last_rech_8    date_of_last_rech_8         3.515765
# date_of_last_rech_7    date_of_last_rech_7         1.762882
# date_of_last_rech_6    date_of_last_rech_6         1.572880
# last_date_of_month_8  last_date_of_month_8         1.047158
# std_og_t2o_mou              std_og_t2o_mou         1.002871
# loc_ic_t2o_mou              loc_ic_t2o_mou         1.002871
# loc_og_t2o_mou              loc_og_t2o_mou         1.002871
# last_date_of_month_7  last_date_of_month_7         0.570008

# %%
# Last date of month is common for all so filling those values with the last date value 
for x in ['last_date_of_month_7','last_date_of_month_8'] :
    churn_df[x].ffill(inplace=True)

# %%
churn_df[churn_df.max_rech_amt_7==0].info(verbose = True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8259 entries, 6 to 69988
# Data columns (total 172 columns):
#  #    Column                    Non-Null Count  Dtype
# ---   ------                    --------------  -----
#  0    id                        8259 non-null   int64
#  1    circle_id                 8259 non-null   int64
#  2    loc_og_t2o_mou            7843 non-null   float64
#  3    std_og_t2o_mou            7843 non-null   float64
#  4    loc_ic_t2o_mou            7843 non-null   float64
#  5    last_date_of_month_6      8259 non-null   datetime64[ns]
#  6    last_date_of_month_7      8259 non-null   datetime64[ns]
#  7    last_date_of_month_8      8259 non-null   datetime64[ns]
#  8    arpu_6                    8259 non-null   float64
#  9    arpu_7                    8259 non-null   float64
#  10   arpu_8                    8259 non-null   float64
#  11   onnet_mou_6               7180 non-null   float64
#  12   onnet_mou_7               6097 non-null   float64
#  13   onnet_mou_8               6503 non-null   float64
#  14   offnet_mou_6              7180 non-null   float64
#  15   offnet_mou_7              6097 non-null   float64
#  16   offnet_mou_8              6503 non-null   float64
#  17   roam_ic_mou_6             7180 non-null   float64
#  18   roam_ic_mou_7             6097 non-null   float64
#  19   roam_ic_mou_8             6503 non-null   float64
#  20   roam_og_mou_6             7180 non-null   float64
#  21   roam_og_mou_7             6097 non-null   float64
#  22   roam_og_mou_8             6503 non-null   float64
#  23   loc_og_t2t_mou_6          7180 non-null   float64
#  24   loc_og_t2t_mou_7          6097 non-null   float64
#  25   loc_og_t2t_mou_8          6503 non-null   float64
#  26   loc_og_t2m_mou_6          7180 non-null   float64
#  27   loc_og_t2m_mou_7          6097 non-null   float64
#  28   loc_og_t2m_mou_8          6503 non-null   float64
#  29   loc_og_t2f_mou_6          7180 non-null   float64
#  30   loc_og_t2f_mou_7          6097 non-null   float64
#  31   loc_og_t2f_mou_8          6503 non-null   float64
#  32   loc_og_t2c_mou_6          7180 non-null   float64
#  33   loc_og_t2c_mou_7          6097 non-null   float64
#  34   loc_og_t2c_mou_8          6503 non-null   float64
#  35   loc_og_mou_6              7180 non-null   float64
#  36   loc_og_mou_7              6097 non-null   float64
#  37   loc_og_mou_8              6503 non-null   float64
#  38   std_og_t2t_mou_6          7180 non-null   float64
#  39   std_og_t2t_mou_7          6097 non-null   float64
#  40   std_og_t2t_mou_8          6503 non-null   float64
#  41   std_og_t2m_mou_6          7180 non-null   float64
#  42   std_og_t2m_mou_7          6097 non-null   float64
#  43   std_og_t2m_mou_8          6503 non-null   float64
#  44   std_og_t2f_mou_6          7180 non-null   float64
#  45   std_og_t2f_mou_7          6097 non-null   float64
#  46   std_og_t2f_mou_8          6503 non-null   float64
#  47   std_og_t2c_mou_6          7180 non-null   float64
#  48   std_og_t2c_mou_7          6097 non-null   float64
#  49   std_og_t2c_mou_8          6503 non-null   float64
#  50   std_og_mou_6              7180 non-null   float64
#  51   std_og_mou_7              6097 non-null   float64
#  52   std_og_mou_8              6503 non-null   float64
#  53   isd_og_mou_6              7180 non-null   float64
#  54   isd_og_mou_7              6097 non-null   float64
#  55   isd_og_mou_8              6503 non-null   float64
#  56   spl_og_mou_6              7180 non-null   float64
#  57   spl_og_mou_7              6097 non-null   float64
#  58   spl_og_mou_8              6503 non-null   float64
#  59   og_others_6               7180 non-null   float64
#  60   og_others_7               6097 non-null   float64
#  61   og_others_8               6503 non-null   float64
#  62   total_og_mou_6            8259 non-null   float64
#  63   total_og_mou_7            8259 non-null   float64
#  64   total_og_mou_8            8259 non-null   float64
#  65   loc_ic_t2t_mou_6          7180 non-null   float64
#  66   loc_ic_t2t_mou_7          6097 non-null   float64
#  67   loc_ic_t2t_mou_8          6503 non-null   float64
#  68   loc_ic_t2m_mou_6          7180 non-null   float64
#  69   loc_ic_t2m_mou_7          6097 non-null   float64
#  70   loc_ic_t2m_mou_8          6503 non-null   float64
#  71   loc_ic_t2f_mou_6          7180 non-null   float64
#  72   loc_ic_t2f_mou_7          6097 non-null   float64
#  73   loc_ic_t2f_mou_8          6503 non-null   float64
#  74   loc_ic_mou_6              7180 non-null   float64
#  75   loc_ic_mou_7              6097 non-null   float64
#  76   loc_ic_mou_8              6503 non-null   float64
#  77   std_ic_t2t_mou_6          7180 non-null   float64
#  78   std_ic_t2t_mou_7          6097 non-null   float64
#  79   std_ic_t2t_mou_8          6503 non-null   float64
#  80   std_ic_t2m_mou_6          7180 non-null   float64
#  81   std_ic_t2m_mou_7          6097 non-null   float64
#  82   std_ic_t2m_mou_8          6503 non-null   float64
#  83   std_ic_t2f_mou_6          7180 non-null   float64
#  84   std_ic_t2f_mou_7          6097 non-null   float64
#  85   std_ic_t2f_mou_8          6503 non-null   float64
#  86   std_ic_t2o_mou_6          7180 non-null   float64
#  87   std_ic_t2o_mou_7          6097 non-null   float64
#  88   std_ic_t2o_mou_8          6503 non-null   float64
#  89   std_ic_mou_6              7180 non-null   float64
#  90   std_ic_mou_7              6097 non-null   float64
#  91   std_ic_mou_8              6503 non-null   float64
#  92   total_ic_mou_6            8259 non-null   float64
#  93   total_ic_mou_7            8259 non-null   float64
#  94   total_ic_mou_8            8259 non-null   float64
#  95   spl_ic_mou_6              7180 non-null   float64
#  96   spl_ic_mou_7              6097 non-null   float64
#  97   spl_ic_mou_8              6503 non-null   float64
#  98   isd_ic_mou_6              7180 non-null   float64
#  99   isd_ic_mou_7              6097 non-null   float64
#  100  isd_ic_mou_8              6503 non-null   float64
#  101  ic_others_6               7180 non-null   float64
#  102  ic_others_7               6097 non-null   float64
#  103  ic_others_8               6503 non-null   float64
#  104  total_rech_num_6          8259 non-null   int64
#  105  total_rech_num_7          8259 non-null   int64
#  106  total_rech_num_8          8259 non-null   int64
#  107  total_rech_amt_6          8259 non-null   int64
#  108  total_rech_amt_7          8259 non-null   int64
#  109  total_rech_amt_8          8259 non-null   int64
#  110  max_rech_amt_6            8259 non-null   int64
#  111  max_rech_amt_7            8259 non-null   int64
#  112  max_rech_amt_8            8259 non-null   int64
#  113  date_of_last_rech_6       7894 non-null   datetime64[ns]
#  114  date_of_last_rech_7       7025 non-null   datetime64[ns]
#  115  date_of_last_rech_8       7075 non-null   datetime64[ns]
#  116  last_day_rch_amt_6        8259 non-null   int64
#  117  last_day_rch_amt_7        8259 non-null   int64
#  118  last_day_rch_amt_8        8259 non-null   int64
#  119  date_of_last_rech_data_6  8259 non-null   object
#  120  date_of_last_rech_data_7  8259 non-null   object
#  121  date_of_last_rech_data_8  8259 non-null   object
#  122  total_rech_data_6         8259 non-null   float64
#  123  total_rech_data_7         8259 non-null   float64
#  124  total_rech_data_8         8259 non-null   float64
#  125  max_rech_data_6           8259 non-null   float64
#  126  max_rech_data_7           8259 non-null   float64
#  127  max_rech_data_8           8259 non-null   float64
#  128  count_rech_2g_6           1293 non-null   float64
#  129  count_rech_2g_7           234 non-null    float64
#  130  count_rech_2g_8           1156 non-null   float64
#  131  count_rech_3g_6           1293 non-null   float64
#  132  count_rech_3g_7           234 non-null    float64
#  133  count_rech_3g_8           1156 non-null   float64
#  134  av_rech_amt_data_6        8259 non-null   float64
#  135  av_rech_amt_data_7        8259 non-null   float64
#  136  av_rech_amt_data_8        8259 non-null   float64
#  137  vol_2g_mb_6               8259 non-null   float64
#  138  vol_2g_mb_7               8259 non-null   float64
#  139  vol_2g_mb_8               8259 non-null   float64
#  140  vol_3g_mb_6               8259 non-null   float64
#  141  vol_3g_mb_7               8259 non-null   float64
#  142  vol_3g_mb_8               8259 non-null   float64
#  143  arpu_3g_6                 1293 non-null   float64
#  144  arpu_3g_7                 234 non-null    float64
#  145  arpu_3g_8                 1156 non-null   float64
#  146  arpu_2g_6                 1293 non-null   float64
#  147  arpu_2g_7                 234 non-null    float64
#  148  arpu_2g_8                 1156 non-null   float64
#  149  night_pck_user_6          1293 non-null   float64
#  150  night_pck_user_7          234 non-null    float64
#  151  night_pck_user_8          1156 non-null   float64
#  152  monthly_2g_6              8259 non-null   int64
#  153  monthly_2g_7              8259 non-null   int64
#  154  monthly_2g_8              8259 non-null   int64
#  155  sachet_2g_6               8259 non-null   int64
#  156  sachet_2g_7               8259 non-null   int64
#  157  sachet_2g_8               8259 non-null   int64
#  158  monthly_3g_6              8259 non-null   int64
#  159  monthly_3g_7              8259 non-null   int64
#  160  monthly_3g_8              8259 non-null   int64
#  161  sachet_3g_6               8259 non-null   int64
#  162  sachet_3g_7               8259 non-null   int64
#  163  sachet_3g_8               8259 non-null   int64
#  164  fb_user_6                 1293 non-null   float64
#  165  fb_user_7                 234 non-null    float64
#  166  fb_user_8                 1156 non-null   float64
#  167  aon                       8259 non-null   int64
#  168  aug_vbc_3g                8259 non-null   float64
#  169  jul_vbc_3g                8259 non-null   float64
#  170  jun_vbc_3g                8259 non-null   float64
#  171  churn_probability         8259 non-null   int64
# dtypes: datetime64[ns](6), float64(135), int64(28), object(3)
# memory usage: 10.9+ MB

# %%
# We can fill the missing data with 0 in all the cases 
churn_df.fillna(0,inplace=True)

# %%
percent_missing = churn_df.isnull().sum() * 100 / len(churn_df)
missing_value_df = pd.DataFrame({'column_name': churn_df.columns,
                                 'percent_missing': percent_missing})
missing_value_df.sort_values('percent_missing', inplace=True, ascending= False)
missing_value_df[missing_value_df.percent_missing>0]
# Out:
# Empty DataFrame
# Columns: [column_name, percent_missing]
# Index: []

# %% [markdown]
# ### All missing values filled with 0 as they are all 0 value from what we undersand looking at the data
# ### We can create new features from the given data

# %%
#we can make a new column that is the total recharge value for data for each month this will help us get our high value customers
churn_df['total_rech_amt_data_6']=churn_df.total_rech_data_6*churn_df.av_rech_amt_data_6
churn_df['total_rech_amt_data_7']=churn_df.total_rech_data_7*churn_df.av_rech_amt_data_7
churn_df['total_rech_amt_data_8']=churn_df.total_rech_data_8*churn_df.av_rech_amt_data_8

# %%
# Lets look at the churn rate 
sns.countplot(data=churn_df,x='churn_probability')
# Out:
# <AxesSubplot:xlabel='churn_probability', ylabel='count'>

# %%
#% of churn 
churn_per=(len(churn_df[churn_df.churn_probability==1])/len(churn_df))
churn_per*100
# Out:
# 10.188716981671167

# %% [markdown]
# ### 10% of customers are expected to churn .
# Lets break out the high value customers

# %%
churn_df['tot_rech']=(churn_df.total_rech_amt_6+churn_df.total_rech_amt_7+churn_df.total_rech_amt_8)+(churn_df.total_rech_amt_data_6+churn_df.total_rech_amt_data_7+churn_df.total_rech_amt_data_8)
churn_df['avg_rech']=churn_df['tot_rech']/3

# %%
highval_cutoff=churn_df.avg_rech.quantile(0.7)

# %%
highval_cutoff
# Out:
# 484.3333333333333

# %% [markdown]
# The high Value clients have a avg spending of $484 per month including the data and regular rechage

# %%
highValue_df=churn_df[churn_df.avg_rech>484].copy()
len(highValue_df)
# Out:
# 21001

# %% [markdown]
# we have 21001 high value customers in the data set
# Lets see how many of them are expected to churn

# %%
len(highValue_df[highValue_df.churn_probability==1])
# Out:
# 1257

# %% [markdown]
# There are 1257 peopel who are expected to churn who are high value customers of the service provieder

# %% [markdown]
# # Dropping Columns
# Lests look at the columns that can be dropped as they do not have any information in them

# %%
uni_count=pd.DataFrame(churn_df.nunique(axis=0))

# %%
uni_count.sort_values(0)
# Out:
#                               0
# std_ic_t2o_mou_8              1
# std_ic_t2o_mou_6              1
# std_og_t2c_mou_6              1
# std_og_t2c_mou_7              1
# std_og_t2c_mou_8              1
# last_date_of_month_8          1
# std_ic_t2o_mou_7              1
# last_date_of_month_6          1
# last_date_of_month_7          1
# loc_og_t2o_mou                1
# std_og_t2o_mou                1
# loc_ic_t2o_mou                1
# circle_id                     1
# fb_user_8                     2
# fb_user_7                     2
# fb_user_6                     2
# churn_probability             2
# night_pck_user_6              2
# night_pck_user_7              2
# night_pck_user_8              2
# monthly_2g_6                  5
# monthly_2g_8                  6
# monthly_2g_7                  6
# monthly_3g_6                 10
# monthly_3g_8                 12
# monthly_3g_7                 13
# count_rech_3g_6              23
# sachet_3g_6                  23
# sachet_3g_7                  26
# count_rech_3g_7              27
# sachet_3g_8                  28
# count_rech_3g_8              29
# sachet_2g_6                  30
# count_rech_2g_6              30
# date_of_last_rech_data_6     31
# date_of_last_rech_6          31
# date_of_last_rech_data_8     32
# date_of_last_rech_data_7     32
# date_of_last_rech_8          32
# sachet_2g_8                  32
# date_of_last_rech_7          32
# count_rech_2g_8              33
# sachet_2g_7                  33
# count_rech_2g_7              33
# total_rech_data_6            37
# total_rech_data_7            42
# total_rech_data_8            45
# max_rech_data_7              46
# max_rech_data_6              48
# max_rech_data_8              50
# spl_ic_mou_6                 78
# total_rech_num_8             92
# total_rech_num_6             94
# spl_ic_mou_8                 95
# total_rech_num_7             96
# spl_ic_mou_7                103
# og_others_7                 148
# last_day_rch_amt_7          166
# max_rech_amt_7              178
# og_others_8                 179
# last_day_rch_amt_6          179
# max_rech_amt_6              190
# last_day_rch_amt_8          191
# max_rech_amt_8              202
# av_rech_amt_data_6          793
# av_rech_amt_data_7          838
# av_rech_amt_data_8          856
# og_others_6                 914
# isd_og_mou_8               1008
# isd_og_mou_7               1084
# isd_og_mou_6               1103
# total_rech_amt_data_6      1398
# total_rech_amt_data_7      1490
# total_rech_amt_data_8      1521
# ic_others_6                1523
# ic_others_8                1565
# ic_others_7                1658
# loc_og_t2c_mou_6           1945
# std_og_t2f_mou_8           1945
# std_og_t2f_mou_7           1991
# std_og_t2f_mou_6           2074
# loc_og_t2c_mou_7           2103
# total_rech_amt_6           2108
# total_rech_amt_7           2147
# total_rech_amt_8           2149
# loc_og_t2c_mou_8           2204
# std_ic_t2f_mou_8           2583
# std_ic_t2f_mou_6           2624
# std_ic_t2f_mou_7           2695
# loc_og_t2f_mou_8           3311
# loc_og_t2f_mou_7           3365
# loc_og_t2f_mou_6           3376
# aon                        3455
# spl_og_mou_6               3503
# spl_og_mou_7               3827
# spl_og_mou_8               3848
# roam_ic_mou_7              4240
# roam_ic_mou_8              4252
# isd_ic_mou_6               4421
# isd_ic_mou_7               4640
# isd_ic_mou_8               4694
# arpu_2g_7                  5056
# arpu_2g_8                  5132
# roam_og_mou_8              5215
# roam_og_mou_7              5305
# roam_ic_mou_6              5306
# std_ic_t2t_mou_6           5323
# std_ic_t2t_mou_8           5367
# arpu_2g_6                  5389
# arpu_3g_7                  5389
# std_ic_t2t_mou_7           5479
# arpu_3g_6                  5506
# arpu_3g_8                  5816
# loc_ic_t2f_mou_8           6092
# loc_ic_t2f_mou_6           6200
# loc_ic_t2f_mou_7           6287
# roam_og_mou_6              6568
# avg_rech                   7049
# tot_rech                   7049
# std_ic_t2m_mou_8           7906
# std_ic_t2m_mou_6           7931
# std_ic_t2m_mou_7           8033
# jun_vbc_3g                 9617
# vol_3g_mb_6                9768
# std_ic_mou_6               9876
# std_ic_mou_8               9939
# std_ic_mou_7              10112
# jul_vbc_3g                10257
# vol_3g_mb_7               10296
# aug_vbc_3g                10609
# vol_3g_mb_8               10663
# loc_og_t2t_mou_8          11296
# vol_2g_mb_8               11359
# loc_og_t2t_mou_7          11359
# vol_2g_mb_7               11443
# loc_ic_t2t_mou_8          11446
# loc_og_t2t_mou_6          11491
# vol_2g_mb_6               11494
# loc_ic_t2t_mou_7          11595
# loc_ic_t2t_mou_6          11637
# std_og_t2t_mou_8          14483
# std_og_t2t_mou_6          14554
# std_og_t2t_mou_7          14745
# std_og_t2m_mou_8          15968
# std_og_t2m_mou_6          16059
# std_og_t2m_mou_7          16234
# loc_og_t2m_mou_8          17616
# loc_og_t2m_mou_7          17641
# loc_og_t2m_mou_6          17848
# loc_ic_t2m_mou_7          18945
# loc_ic_t2m_mou_8          19022
# loc_ic_t2m_mou_6          19034
# onnet_mou_8               19725
# onnet_mou_6               20057
# onnet_mou_7               20076
# std_og_mou_8              21745
# std_og_mou_6              21837
# loc_og_mou_8              21950
# loc_og_mou_7              22012
# std_og_mou_7              22088
# loc_og_mou_6              22309
# loc_ic_mou_8              24182
# loc_ic_mou_7              24258
# loc_ic_mou_6              24442
# offnet_mou_8              25995
# offnet_mou_7              26139
# offnet_mou_6              26254
# total_ic_mou_8            27318
# total_ic_mou_7            27418
# total_ic_mou_6            27432
# total_og_mou_8            32897
# total_og_mou_6            33135
# total_og_mou_7            33195
# arpu_8                    60194
# arpu_7                    61425
# arpu_6                    61615
# id                        69999

# %% [markdown]
# ### we can drop all the columns that have

# %%
drop_list=list(uni_count[uni_count[0]==1].index)

# %%
churn_df.drop(drop_list,inplace=True,axis=1)

# %%
churn_df.shape
# Out:
# (69999, 164)

# %%
#ID can also be dropped as its only a primery key and has no addittional information
churn_df.drop('id',axis=1,inplace=True)

# %%
drop_list.append('id')# we need to maintain a list of dropped columns for test set

# %%
highValue_df.drop(drop_list,axis=1,inplace=True)

# %%
# we can concider any column with less than 15 unique values as catagorical.
uni_count=pd.DataFrame(churn_df.nunique(axis=0))#need to restore as we dropped columns
catcols=list(uni_count[uni_count[0]<15].index)
catcols
# Out:
# ['night_pck_user_6',
#  'night_pck_user_7',
#  'night_pck_user_8',
#  'monthly_2g_6',
#  'monthly_2g_7',
#  'monthly_2g_8',
#  'monthly_3g_6',
#  'monthly_3g_7',
#  'monthly_3g_8',
#  'fb_user_6',
#  'fb_user_7',
#  'fb_user_8',
#  'churn_probability']

# %%
num_cols=list(uni_count[uni_count[0]>15].index)
num_cols
# Out:
# ['arpu_6',
#  'arpu_7',
#  'arpu_8',
#  'onnet_mou_6',
#  'onnet_mou_7',
#  'onnet_mou_8',
#  'offnet_mou_6',
#  'offnet_mou_7',
#  'offnet_mou_8',
#  'roam_ic_mou_6',
#  'roam_ic_mou_7',
#  'roam_ic_mou_8',
#  'roam_og_mou_6',
#  'roam_og_mou_7',
#  'roam_og_mou_8',
#  'loc_og_t2t_mou_6',
#  'loc_og_t2t_mou_7',
#  'loc_og_t2t_mou_8',
#  'loc_og_t2m_mou_6',
#  'loc_og_t2m_mou_7',
#  'loc_og_t2m_mou_8',
#  'loc_og_t2f_mou_6',
#  'loc_og_t2f_mou_7',
#  'loc_og_t2f_mou_8',
#  'loc_og_t2c_mou_6',
#  'loc_og_t2c_mou_7',
#  'loc_og_t2c_mou_8',
#  'loc_og_mou_6',
#  'loc_og_mou_7',
#  'loc_og_mou_8',
#  'std_og_t2t_mou_6',
#  'std_og_t2t_mou_7',
#  'std_og_t2t_mou_8',
#  'std_og_t2m_mou_6',
#  'std_og_t2m_mou_7',
#  'std_og_t2m_mou_8',
#  'std_og_t2f_mou_6',
#  'std_og_t2f_mou_7',
#  'std_og_t2f_mou_8',
#  'std_og_mou_6',
#  'std_og_mou_7',
#  'std_og_mou_8',
#  'isd_og_mou_6',
#  'isd_og_mou_7',
#  'isd_og_mou_8',
#  'spl_og_mou_6',
#  'spl_og_mou_7',
#  'spl_og_mou_8',
#  'og_others_6',
#  'og_others_7',
#  'og_others_8',
#  'total_og_mou_6',
#  'total_og_mou_7',
#  'total_og_mou_8',
#  'loc_ic_t2t_mou_6',
#  'loc_ic_t2t_mou_7',
#  'loc_ic_t2t_mou_8',
#  'loc_ic_t2m_mou_6',
#  'loc_ic_t2m_mou_7',
#  'loc_ic_t2m_mou_8',
#  'loc_ic_t2f_mou_6',
#  'loc_ic_t2f_mou_7',
#  'loc_ic_t2f_mou_8',
#  'loc_ic_mou_6',
#  'loc_ic_mou_7',
#  'loc_ic_mou_8',
#  'std_ic_t2t_mou_6',
#  'std_ic_t2t_mou_7',
#  'std_ic_t2t_mou_8',
#  'std_ic_t2m_mou_6',
#  'std_ic_t2m_mou_7',
#  'std_ic_t2m_mou_8',
#  'std_ic_t2f_mou_6',
#  'std_ic_t2f_mou_7',
#  'std_ic_t2f_mou_8',
#  'std_ic_mou_6',
#  'std_ic_mou_7',
#  'std_ic_mou_8',
#  'total_ic_mou_6',
#  'total_ic_mou_7',
#  'total_ic_mou_8',
#  'spl_ic_mou_6',
#  'spl_ic_mou_7',
#  'spl_ic_mou_8',
#  'isd_ic_mou_6',
#  'isd_ic_mou_7',
#  'isd_ic_mou_8',
#  'ic_others_6',
#  'ic_others_7',
#  'ic_others_8',
#  'total_rech_num_6',
#  'total_rech_num_7',
#  'total_rech_num_8',
#  'total_rech_amt_6',
#  'total_rech_amt_7',
#  'total_rech_amt_8',
#  'max_rech_amt_6',
#  'max_rech_amt_7',
#  'max_rech_amt_8',
#  'date_of_last_rech_6',
#  'date_of_last_rech_7',
#  'date_of_last_rech_8',
#  'last_day_rch_amt_6',
#  'last_day_rch_amt_7',
#  'last_day_rch_amt_8',
#  'date_of_last_rech_data_6',
#  'date_of_last_rech_data_7',
#  'date_of_last_rech_data_8',
#  'total_rech_data_6',
#  'total_rech_data_7',
#  'total_rech_data_8',
#  'max_rech_data_6',
#  'max_rech_data_7',
#  'max_rech_data_8',
#  'count_rech_2g_6',
#  'count_rech_2g_7',
#  'count_rech_2g_8',
#  'count_rech_3g_6',
#  'count_rech_3g_7',
#  'count_rech_3g_8',
#  'av_rech_amt_data_6',
#  'av_rech_amt_data_7',
#  'av_rech_amt_data_8',
#  'vol_2g_mb_6',
#  'vol_2g_mb_7',
#  'vol_2g_mb_8',
#  'vol_3g_mb_6',
#  'vol_3g_mb_7',
#  'vol_3g_mb_8',
#  'arpu_3g_6',
#  'arpu_3g_7',
#  'arpu_3g_8',
#  'arpu_2g_6',
#  'arpu_2g_7',
#  'arpu_2g_8',
#  'sachet_2g_6',
#  'sachet_2g_7',
#  'sachet_2g_8',
#  'sachet_3g_6',
#  'sachet_3g_7',
#  'sachet_3g_8',
#  'aon',
#  'aug_vbc_3g',
#  'jul_vbc_3g',
#  'jun_vbc_3g',
#  'total_rech_amt_data_6',
#  'total_rech_amt_data_7',
#  'total_rech_amt_data_8',
#  'tot_rech',
#  'avg_rech']

# %% [markdown]
# # EDA
# ### Lest look at the data visually and see if we can find any strong relations
#
# #### We can focus on the high value customers

# %%
plt.figure(figsize=(20, 40))
r=1
pal=["tab10","hls","husl","Set2","Paired","flare","rocket","cubehelix"]
for c in catcols:
    plt.subplot(4,4,r)
    sns.countplot(data=highValue_df,x=c,hue='churn_probability',palette=random.choice(pal))
    r=r+1
plt.show()

# %% [markdown]
# ### Data shows us the following data .
# * customers that use data are less likely to churn
# * customers who use social media have a lower probabilty of churning
# * customers who use the night pack also have a lower churn probaility

# %%
plt.figure(figsize=(5,15))
sns.boxenplot(data=highValue_df,x='churn_probability',y='avg_rech')
plt.show()
